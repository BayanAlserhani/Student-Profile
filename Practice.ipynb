# %%
import yfinance as yf
import pandas as pd
import pandas
from pandas_datareader import data as pdr

# %%
yf.pdr_override()

# %%
pd.options.mode.chained_assignment = None
#this is for the message "A value is trying to be set on a copy of a slice from a DataFrame"

# %%
symbols = ['SPY', 'TLT', 'XLF']
data = pdr.get_data_yahoo(symbols)
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
df = data.dropna()
df
# Out:
#              Adj Close                              Close              \
#                    SPY         TLT        XLF         SPY         TLT
# Date
# 2002-07-30   62.595913   42.305950  12.362281   90.940002   81.519997
# 2002-07-31   62.747334   42.830132  12.552891   91.160004   82.529999
# 2002-08-01   61.109123   43.074028  12.242475   88.779999   83.000000
# 2002-08-02   59.739361   43.515182  11.932057   86.790001   83.849998
# 2002-08-05   57.660618   43.707207  11.463700   83.769997   84.220001
# ...                ...         ...        ...         ...         ...
# 2021-11-11  463.769989  147.979996  40.060001  463.769989  147.979996
# 2021-11-12  467.269989  147.330002  40.150002  467.269989  147.330002
# 2021-11-15  467.429993  145.479996  40.150002  467.429993  145.479996
# 2021-11-16  469.279999  145.110001  40.110001  469.279999  145.110001
# 2021-11-17  468.730011  144.679993  39.682999  468.730011  144.679993
#
# ...

# %%
symbols
df = df.loc[:,{("High","SPY"),("Close", "TLT")}]
df
# Out:
#                   High       Close
#                    SPY         TLT
# Date
# 2002-07-30   91.400002   81.519997
# 2002-07-31   91.550003   82.529999
# 2002-08-01   91.349998   83.000000
# 2002-08-02   88.910004   83.849998
# 2002-08-05   86.930000   84.220001
# ...                ...         ...
# 2021-11-11  465.290009  147.979996
# 2021-11-12  467.859985  147.330002
# 2021-11-15  468.809998  145.479996
# 2021-11-16  470.489990  145.110001
# 2021-11-17  469.029999  144.679993
#
# [4862 rows x 2 columns]

# %%
df_spy = pdr.get_data_yahoo('SPY')
df_tlt = pdr.get_data_yahoo('TLT')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
df_spy
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-29   43.968750   43.968750   43.750000   43.937500   25.717394
# 1993-02-01   43.968750   44.250000   43.968750   44.250000   25.900282
# 1993-02-02   44.218750   44.375000   44.125000   44.343750   25.955177
# 1993-02-03   44.406250   44.843750   44.375000   44.812500   26.229532
# 1993-02-04   44.968750   45.093750   44.468750   45.000000   26.339281
# ...                ...         ...         ...         ...         ...
# 2021-11-11  465.209991  465.290009  463.750000  463.769989  463.769989
# 2021-11-12  465.119995  467.859985  464.109985  467.269989  467.269989
# 2021-11-15  468.640015  468.809998  466.230011  467.429993  467.429993
# 2021-11-16  467.149994  470.489990  467.070007  469.279999  469.279999
# 2021-11-17  469.000000  469.029999  467.480011  468.501892  468.501892
#
#               Volume
# Date
# 1993-01-29   1003200
# 1993-02-01    480500
# 1993-02-02    201300
# ...

# %%
df_spy = df_spy[['Open', 'Close']]
df_spy
# Out:
#                   Open       Close
# Date
# 1993-01-29   43.968750   43.937500
# 1993-02-01   43.968750   44.250000
# 1993-02-02   44.218750   44.343750
# 1993-02-03   44.406250   44.812500
# 1993-02-04   44.968750   45.000000
# ...                ...         ...
# 2021-11-11  465.209991  463.769989
# 2021-11-12  465.119995  467.269989
# 2021-11-15  468.640015  467.429993
# 2021-11-16  467.149994  469.279999
# 2021-11-17  469.000000  468.501892
#
# [7255 rows x 2 columns]

# %%
df_spy.rename(columns={'Open':"Open_SPY", 'Close':"Close_SPY"},inplace=True)
df_spy
# Out:
#               Open_SPY   Close_SPY
# Date
# 1993-01-29   43.968750   43.937500
# 1993-02-01   43.968750   44.250000
# 1993-02-02   44.218750   44.343750
# 1993-02-03   44.406250   44.812500
# 1993-02-04   44.968750   45.000000
# ...                ...         ...
# 2021-11-11  465.209991  463.769989
# 2021-11-12  465.119995  467.269989
# 2021-11-15  468.640015  467.429993
# 2021-11-16  467.149994  469.279999
# 2021-11-17  469.000000  468.501892
#
# [7255 rows x 2 columns]

# %%
df_1 = pdr.get_data_yahoo('SPY')[['Open', 'Close']].rename(columns={'Open':"Open_SPY", 'Close':"Close_SPY"},inplace=True)
df_2 = pdr.get_data_yahoo('TLT')[['Open', 'Close']].rename(columns={'Open':"Open_TLT", 'Close':"Close_TLT"},inplace=True)
df_3 = pdr.get_data_yahoo('XLF')[['Open', 'Close']].rename(columns={'Open':"Open_XLF", 'Close':"Close_XLF"},inplace=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
df_1

# %%
final_df = pd.concat([df_1,df_2,df_3], axis=1).dropna()
final_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-0ad25d3577ca> in <module>
# ----> 1 final_df = pd.concat([df_1,df_2,df_3], axis=1).dropna()
#       2 final_df
#
# ~\anaconda3\ANACONDA3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     283     ValueError: Indexes have overlapping values: ['a']
#     284     """
# --> 285     op = _Concatenator(
#     286         objs,
#     287         axis=axis,
#
# ~\anaconda3\ANACONDA3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     358
#     359         if len(objs) == 0:
# --> 360             raise ValueError("All objects passed were None")
#     361
# ...
